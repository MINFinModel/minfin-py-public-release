# %% [markdown]
# # To translate finincial instruments

# %%
donor_discount_rate = 0.04
donor_discount_recipient = 0.0533

#We need Grant / Loan, Grant and loan
#Grant Element
